# %%
import iris
import matplotlib.pyplot as plt
import numpy as np

# %%
infile = '/g/data/r87/dbi599/CMIP6/DAMIP/BCC/BCC-CSM2-MR/hist-GHG/r1i1p1f1/Ayr/areacella/gn/v20190426/areacella-pe-region-sum-dedrifted_Ayr_BCC-CSM2-MR_hist-GHG_r1i1p1f1_gn_185001-202012.nc'

# %%
cube = iris.load_cube(infile)

# %%
cube
# Out:
# <iris 'Cube' of cell_area / (m2) (time: 171; region: 5)>

# %%
plt.plot(cube.data[:, 0], label='SH precip')
plt.plot(cube.data[:, 1], label='SH evap')
plt.plot(cube.data[:, 2], label='tropical precip')
plt.plot(cube.data[:, 3], label='NH evap')
plt.plot(cube.data[:, 4], label='NH precip')
plt.legend()
plt.show()
