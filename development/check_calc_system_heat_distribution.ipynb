# %% [markdown]
# Quick check of output from `calc_system_heat_distribution.py`

# %%
import matplotlib.pyplot as plt
import iris
import iris.plot as iplt
import iris.quickplot as qplt

# %%
# %matplotlib inline

# %%
infile = '/g/data/r87/dbi599/temp/energy-budget_mon_CSIRO-Mk3-6-0_historicalMisc_r1i1p4_all.nc'
cubes = iris.load(infile)
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)

# %%
print(cubes)
# Out:
# 0: Surface Upwelling Shortwave Radiation sh ocean sum / (W) (time: 163)
# 1: Surface Downwelling Shortwave Radiation sh sum / (W) (time: 163)
# 2: TOA Outgoing Longwave Radiation sh sum / (W) (time: 163)
# 3: Surface Upward Latent Heat Flux nh ocean sum / (W) (time: 163)
# 4: Surface Upward Sensible Heat Flux nh land sum / (W) (time: 163)
# 5: Surface Upward Latent Heat Flux sh land sum / (W) (time: 163)
# 6: Surface Downwelling Shortwave Radiation sh land sum / (W) (time: 163)
# 7: Surface Upward Sensible Heat Flux nh sum / (W) (time: 163)
# 8: Surface Downwelling Net Flux in Air sh sum / (W) (time: 163)
# 9: Surface Downwelling Shortwave Radiation sh ocean sum / (W) (time: 163)
# 10: Surface Upward Sensible Heat Flux nh ocean sum / (W) (time: 163)
# 11: Surface Upwelling Shortwave Radiation sh land sum / (W) (time: 163)
# 12: Surface Downwelling Longwave Radiation nh sum / (W) (time: 163)
# 13: TOA Incoming Net Flux sh sum / (W)  (time: 163)
# 14: Surface Downwelling Net Flux in Air sh land sum / (W) (time: 163)
# 15: Surface Upwelling Longwave Radiation sh ocean sum / (W) (time: 163)
# 16: Surface Downwelling Shortwave Radiation nh land sum / (W) (time: 163)
# 17: Surface Upwelling Longwave Radiation sh sum / (W) (time: 163)
# 18: Surface Upward Sensible Heat Flux sh sum / (W) (time: 163)
# 19: Surface Downwelling Shortwave Radiation nh ocean sum / (W) (time: 163)
# 20: Surface Downwelling Net Flux in Air sh ocean sum / (W) (time: 163)
# 21: TOA Incoming Net Flux nh sum / (W)  (time: 163)
# 22: TOA Outgoing Shortwave Radiation sh sum / (W) (time: 163)
# 23: Surface Upwelling Longwave Radiation nh land sum / (W) (time: 163)
# 24: Surface Downwelling Net Flux in Air nh land sum / (W) (time: 163)
# 25: TOA Outgoing Longwave Radiation nh sum / (W) (time: 163)
# 26: Surface Upward Latent Heat Flux sh ocean sum / (W) (time: 163)
# 27: Surface Downwelling Longwave Radiation nh ocean sum / (W) (time: 163)
# 28: Surface Upwelling Shortwave Radiation nh land sum / (W) (time: 163)
# 29: Surface Upwelling Shortwave Radiation sh sum / (W) (time: 163)
# 30: Surface Upward Latent Heat Flux nh sum / (W) (time: 163)
# 31: Surface Downwelling Longwave Radiation sh ocean sum / (W) (time: 163)
# 32: Surface Upward Latent Heat Flux nh land sum / (W) (time: 163)
# 33: Surface Upwelling Shortwave Radiation nh ocean sum / (W) (time: 163)
# 34: Surface Upwelling Shortwave Radiation nh sum / (W) (time: 163)
# 35: TOA Outgoing Shortwave Radiation nh sum / (W) (time: 163)
# 36: Surface Downwelling Longwave Radiation nh land sum / (W) (time: 163)
# 37: Downward Heat Flux at Sea Water Surface nh ocean sum / (W) (time: 163)
# 38: Surface Upward Sensible Heat Flux sh ocean sum / (W) (time: 163)
# 39: Surface Downwelling Net Flux in Air nh sum / (W) (time: 163)
# 40: Downward Heat Flux at Sea Water Surface sh ocean sum / (W) (time: 163)
# 41: Surface Downwelling Shortwave Radiation nh sum / (W) (time: 163)
# 42: Surface Downwelling Net Flux in Air nh ocean sum / (W) (time: 163)
# 43: Surface Downwelling Longwave Radiation sh land sum / (W) (time: 163)
# 44: TOA Incident Shortwave Radiation nh sum / (W) (time: 163)
# 45: Surface Upwelling Longwave Radiation nh sum / (W) (time: 163)
# 46: Surface Upwelling Longwave Radiation nh ocean sum / (W) (time: 163)
# 47: Surface Downwelling Longwave Radiation sh sum / (W) (time: 163)
# 48: Surface Upward Latent Heat Flux sh sum / (W) (time: 163)
# 49: TOA Incident Shortwave Radiation sh sum / (W) (time: 163)
# 50: Surface Upwelling Longwave Radiation sh land sum / (W) (time: 163)
# 51: Surface Upward Sensible Heat Flux sh land sum / (W) (time: 163)

# %% [markdown]
# ## Top of atmosphere

# %% [markdown]
# ### TOA incident shortwave

# %%
rsdt_nh_cube = iris.load_cube(infile, 'TOA Incident Shortwave Radiation nh sum')
qplt.plot(rsdt_nh_cube)
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %%
rsdt_sh_cube = iris.load_cube(infile, 'TOA Incident Shortwave Radiation sh sum')
qplt.plot(rsdt_sh_cube)
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %% [markdown]
# ### TOA outgoing shotwave

# %%
rsut_nh_cube = iris.load_cube(infile, 'TOA Outgoing Shortwave Radiation nh sum')
rsut_sh_cube = iris.load_cube(infile, 'TOA Outgoing Shortwave Radiation sh sum')

qplt.plot(rsut_nh_cube, label='NH')
qplt.plot(rsut_sh_cube, label='SH')
plt.legend()
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %% [markdown]
# ### TOA outgoing longwave

# %%
rlut_nh_cube = iris.load_cube(infile, 'TOA Outgoing Longwave Radiation nh sum')
rlut_sh_cube = iris.load_cube(infile, 'TOA Outgoing Longwave Radiation sh sum')

qplt.plot(rlut_nh_cube, label='NH')
qplt.plot(rlut_sh_cube, label='SH')
plt.legend()
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %% [markdown]
# ### TOA net radiative flux

# %%
rndt_nh_cube = iris.load_cube(infile, 'TOA Incoming Net Flux nh sum')
rndt_sh_cube = iris.load_cube(infile, 'TOA Incoming Net Flux sh sum')

qplt.plot(rndt_nh_cube, label='NH')
qplt.plot(rndt_sh_cube, label='SH')
plt.legend()
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %% [markdown]
# ## Atmosphere (over ocean)

# %% [markdown]
# ### Downwelling shortwave

# %%
rsds_nh_cube = iris.load_cube(infile, 'Surface Downwelling Shortwave Radiation nh ocean sum')
qplt.plot(rsds_nh_cube, label='NH')
plt.legend()
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %%
rsds_sh_cube = iris.load_cube(infile, 'Surface Downwelling Shortwave Radiation sh ocean sum')

qplt.plot(rsds_sh_cube, label='SH')
plt.legend()
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %% [markdown]
# ### Upwelling shortwave

# %%
rsus_nh_cube = iris.load_cube(infile, 'Surface Upwelling Shortwave Radiation nh ocean sum')
qplt.plot(rsus_nh_cube, label='NH')
plt.legend()
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %% [markdown]
# ### Net radiative flux at ocean surface

# %%
rnds_nh_cube = iris.load_cube(infile, 'Surface Downwelling Net Flux in Air nh ocean sum')
qplt.plot(rnds_nh_cube, label='NH')
plt.legend()
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %%
rnds_sh_cube = iris.load_cube(infile, 'Surface Downwelling Net Flux in Air sh ocean sum')
qplt.plot(rnds_sh_cube, label='SH')
plt.legend()
plt.show()
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/matplotlib/ticker.py:1693: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'
