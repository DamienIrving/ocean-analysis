# %% [markdown]
# Quick check of output from `calc_trend_fields.py`

# %%
import matplotlib.pyplot as plt
import iris
import iris.plot as iplt
import iris.quickplot as qplt

# %%
# %matplotlib inline

# %%
cubes = iris.load('/g/data/r87/dbi599/temp/test_trend_field.nc')
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean/lib/python3.6/site-packages/iris/fileformats/cf.py:1143: IrisDeprecation: NetCDF default loading behaviour currently does not expose variables which define reference surfaces for dimensionless vertical coordinates as independent Cubes. This behaviour is deprecated in favour of automatic promotion to Cubes. To switch to the new behaviour, set iris.FUTURE.netcdf_promote to True.
#   warn_deprecated(msg)

# %%
print(cubes)
# Out:
# 0: Surface Upwelling Longwave Radiation land trend / (W) (latitude: 96; longitude: 192)
# 1: Surface Upwelling Longwave Radiation zonal land sum climatology / (W) (latitude: 96)
# 2: Surface Upwelling Longwave Radiation zonal ocean sum trend / (W) (latitude: 96)
# 3: Surface Upwelling Longwave Radiation ocean climatology / (W) (latitude: 96; longitude: 192)
# 4: Surface Upwelling Longwave Radiation land climatology / (W) (latitude: 96; longitude: 192)
# 5: Surface Upwelling Longwave Radiation zonal sum trend / (W) (latitude: 96)
# 6: Surface Upwelling Longwave Radiation zonal ocean sum climatology / (W) (latitude: 96)
# 7: Surface Upwelling Longwave Radiation zonal land sum trend / (W) (latitude: 96)
# 8: Surface Upwelling Longwave Radiation ocean trend / (W) (latitude: 96; longitude: 192)
# 9: Surface Upwelling Longwave Radiation climatology / (W) (latitude: 96; longitude: 192)
# 10: Surface Upwelling Longwave Radiation zonal sum climatology / (W) (latitude: 96)
# 11: Surface Upwelling Longwave Radiation trend / (W) (latitude: 96; longitude: 192)

# %%
levels = [-2.5e9, -2.0e9, -1.5e9, -1.0e9, -0.5e9, 0, 0.5e9, 1.0e9, 1.5e9, 2.0e9, 2.5e9]

qplt.contourf(cubes[8], cmap='RdBu_r', levels=levels)
plt.gca().coastlines()
plt.show()

# %%
# 2D plots
iplt.plot(cubes[5])

# %%
2.5e9
# Out:
# 2500000000.0
