# %%
import glob
import xarray as xr
import iris
from iris.experimental.equalise_cubes import equalise_attributes

# %%
temp_files = glob.glob('/g/data/fs38/publications/CMIP6/FAFMIP/CSIRO-ARCCSS/ACCESS-CM2/faf-passiveheat/r1i1p1f1/Omon/bigthetao/gn/latest/*.nc')
temp_files.sort()

# %%
temp_files
# Out:
# ['/g/data/fs38/publications/CMIP6/FAFMIP/CSIRO-ARCCSS/ACCESS-CM2/faf-passiveheat/r1i1p1f1/Omon/bigthetao/gn/latest/bigthetao_Omon_ACCESS-CM2_faf-passiveheat_r1i1p1f1_gn_095001-095912.nc',
#  '/g/data/fs38/publications/CMIP6/FAFMIP/CSIRO-ARCCSS/ACCESS-CM2/faf-passiveheat/r1i1p1f1/Omon/bigthetao/gn/latest/bigthetao_Omon_ACCESS-CM2_faf-passiveheat_r1i1p1f1_gn_096001-096912.nc',
#  '/g/data/fs38/publications/CMIP6/FAFMIP/CSIRO-ARCCSS/ACCESS-CM2/faf-passiveheat/r1i1p1f1/Omon/bigthetao/gn/latest/bigthetao_Omon_ACCESS-CM2_faf-passiveheat_r1i1p1f1_gn_097001-097912.nc',
#  '/g/data/fs38/publications/CMIP6/FAFMIP/CSIRO-ARCCSS/ACCESS-CM2/faf-passiveheat/r1i1p1f1/Omon/bigthetao/gn/latest/bigthetao_Omon_ACCESS-CM2_faf-passiveheat_r1i1p1f1_gn_098001-098912.nc',
#  '/g/data/fs38/publications/CMIP6/FAFMIP/CSIRO-ARCCSS/ACCESS-CM2/faf-passiveheat/r1i1p1f1/Omon/bigthetao/gn/latest/bigthetao_Omon_ACCESS-CM2_faf-passiveheat_r1i1p1f1_gn_099001-099912.nc',
# ...

# %% [markdown]
# ### open with xarray

# %%
temp_dset = xr.open_mfdataset(temp_files)
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean3/lib/python3.7/site-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/r87/dbi599/miniconda3/envs/ocean3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# /g/data/r87/dbi599/miniconda3/envs/ocean3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# ...

# %%
temp_dset
# Out:
# <xarray.Dataset>
# Dimensions:             (bnds: 2, i: 360, j: 300, lev: 50, time: 840, vertices: 4)
# Coordinates:
#     latitude            (j, i) float64 dask.array<chunksize=(300, 360), meta=np.ndarray>
#     longitude           (j, i) float64 dask.array<chunksize=(300, 360), meta=np.ndarray>
#   * lev                 (lev) float64 5.0 15.0 25.0 ... 5.499e+03 5.831e+03
#   * j                   (j) int32 0 1 2 3 4 5 6 ... 293 294 295 296 297 298 299
#   * i                   (i) int32 0 1 2 3 4 5 6 ... 353 354 355 356 357 358 359
#   * time                (time) object 0950-01-16 12:00:00 ... 1019-12-16 12:00:00
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     time_bnds           (time, bnds) object dask.array<chunksize=(120, 2), meta=np.ndarray>
#     lev_bnds            (time, lev, bnds) float64 dask.array<chunksize=(120, 50, 2), meta=np.ndarray>
# ...

# %%
temp_dset['bigthetao']
# Out:
# <xarray.DataArray 'bigthetao' (time: 840, lev: 50, j: 300, i: 360)>
# dask.array<concatenate, shape=(840, 50, 300, 360), dtype=float32, chunksize=(120, 50, 300, 360), chunktype=numpy.ndarray>
# Coordinates:
#     latitude   (j, i) float64 dask.array<chunksize=(300, 360), meta=np.ndarray>
#     longitude  (j, i) float64 dask.array<chunksize=(300, 360), meta=np.ndarray>
#   * lev        (lev) float64 5.0 15.0 25.0 ... 5.166e+03 5.499e+03 5.831e+03
#   * j          (j) int32 0 1 2 3 4 5 6 7 8 ... 292 293 294 295 296 297 298 299
#   * i          (i) int32 0 1 2 3 4 5 6 7 8 ... 352 353 354 355 356 357 358 359
#   * time       (time) object 0950-01-16 12:00:00 ... 1019-12-16 12:00:00
# Attributes:
#     standard_name:   sea_water_conservative_temperature
#     long_name:       Sea Water Conservative Temperature
#     comment:         Sea water conservative temperature (this should be contr...
#     units:           degC
#     original_units:  K
# ...

# %% [markdown]
# ## open with iris

# %%
temp_cube_list = iris.load(temp_files, 'sea_water_conservative_temperature')
# Out:
# /g/data/r87/dbi599/miniconda3/envs/ocean3/lib/python3.7/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacello', referenced by netCDF variable 'bigthetao'
#   warnings.warn(message % (variable_name, nc_var_name))
# /g/data/r87/dbi599/miniconda3/envs/ocean3/lib/python3.7/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'volcello', referenced by netCDF variable 'bigthetao'
#   warnings.warn(message % (variable_name, nc_var_name))
# /g/data/r87/dbi599/miniconda3/envs/ocean3/lib/python3.7/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'areacello', referenced by netCDF variable 'bigthetao'
#   warnings.warn(message % (variable_name, nc_var_name))
# /g/data/r87/dbi599/miniconda3/envs/ocean3/lib/python3.7/site-packages/iris/fileformats/cf.py:803: UserWarning: Missing CF-netCDF measure variable 'volcello', referenced by netCDF variable 'bigthetao'
# ...

# %%
temp_cube_list
# Out:
# [<iris 'Cube' of sea_water_conservative_temperature / (degC) (time: 120; depth: 50; cell index along second dimension: 300; cell index along first dimension: 360)>,
# <iris 'Cube' of sea_water_conservative_temperature / (degC) (time: 120; depth: 50; cell index along second dimension: 300; cell index along first dimension: 360)>,
# <iris 'Cube' of sea_water_conservative_temperature / (degC) (time: 120; depth: 50; cell index along second dimension: 300; cell index along first dimension: 360)>,
# <iris 'Cube' of sea_water_conservative_temperature / (degC) (time: 120; depth: 50; cell index along second dimension: 300; cell index along first dimension: 360)>,
# <iris 'Cube' of sea_water_conservative_temperature / (degC) (time: 120; depth: 50; cell index along second dimension: 300; cell index along first dimension: 360)>,
# <iris 'Cube' of sea_water_conservative_temperature / (degC) (time: 120; depth: 50; cell index along second dimension: 300; cell index along first dimension: 360)>,
# ...

# %%
equalise_attributes(temp_cube_list)

# %%
temp_cube = temp_cube_list.concatenate_cube()

# %%
temp_cube
# Out:
# <iris 'Cube' of sea_water_conservative_temperature / (degC) (time: 840; depth: 50; cell index along second dimension: 300; cell index along first dimension: 360)>
